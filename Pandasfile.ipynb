# %% [markdown]
# <a href="https://colab.research.google.com/github/kavirenuk/gdp-dashboard/blob/main/Pandasfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from  google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mplcursors

# %%
filepath = "/content/drive/ My Drive/Colab/insurance.csv"
df = pd.read_csv(filepath)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import matplotlib.pyplot  as plt
import mplcursors
age_c = df.groupby(['age','sex']).size().unstack()

# %%
ax =age_c.plot(kind='bar',figsize=(12,6))
plt.title("Number of Individuals by Age and Gender")
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title="Sex")
plt.grid(axis ='y')
cur =mplcursors.cursor(ax.containers,hover =True)
def on_add(sel):
  bar - el.artist
  idx= sel.index
  age = age_c.index[idx]
  sex = bar.get_label()
  count = bar.datavalues[idx]
  sel.annotation.set_text(f'Age:{age}\nSex:{Sex}\ncount:{count}')

plt.show()

# %%
children_charges = df.groupby('children')['charges'].mean().reset_index()
display(children_charges)
# Out:
#    children       charges
# 0         0  12365.975602
# 1         1  12731.171832
# 2         2  15073.563734
# 3         3  15355.318367
# 4         4  13850.656311
# 5         5   8786.035247

# %%
# @title children

from matplotlib import pyplot as plt
children_charges['children'].plot(kind='hist', bins=20, title='children')
plt.gca().spines[['top', 'right',]].set_visible(False)
